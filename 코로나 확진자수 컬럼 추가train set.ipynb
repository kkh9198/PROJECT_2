# %%
import pandas as pd

# %%
df=pd.read_csv('corona_seoul_1.csv')

# %%
del df['확진일']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '확진일'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-16eb29018b4e> in <module>
# ----> 1 del df['확진일']
#
# ...

# %%
df
# Out:
#     확진월    지역  확진자수
# 0     1   강서구     1
# 1     1   마포구     1
# 2     1   성북구     1
# 3     1   종로구     3
# 4     1   중랑구     1
# 5     2   강남구     7
# 6     2   강동구     4
# 7     2   강서구     1
# 8     2   관악구     4
# 9     2   광진구     1
# 10    2   구로구     1
# 11    2   금천구     1
# 12    2   노원구     8
# 13    2  동대문구     1
# 14    2   동작구     1
# 15    2  서대문구     4
# 16    2   서초구     4
# 17    2   성동구     3
# 18    2   성북구     1
# 19    2   송파구    12
# 20    2   양천구     1
# 21    2  영등포구     2
# 22    2   은평구     7
# 23    2   종로구     8
# 24    3   강남구    34
# 25    3   강동구     6
# 26    3   강북구     5
# 27    3   강서구    20
# 28    3   관악구    30
# 29    3   광진구     5
# 30    3   구로구    33
# 31    3   금천구    11
# 32    3    기타     2
# 33    3   노원구    12
# 34    3   도봉구     6
# 35    3  동대문구    25
# 36    3   동작구    23
# 37    3   마포구    16
# 38    3  서대문구     9
# 39    3   서초구    21
# 40    3   성동구     3
# 41    3   성북구    13
# 42    3   송파구    15
# 43    3   양천구    17
# ...

# %%
df=df[df['지역']!='타시도']

# %%
df=df.groupby(['확진월','지역'])['확진자수'].sum().reset_index()

# %%
df_1=pd.read_csv('Seoul_corona_1.csv')

# %%
df_1
# Out:
#            년  월 매장_시군구            업종명  성별  가구생애주기  이용고객수      이용금액  이용건수
# 0       2019  1    강남구     건강보조식품 소매업   1       1     31   1405000    36
# 1       2019  1    강남구     건강보조식품 소매업   1       2    110  11861050   121
# 2       2019  1    강남구     건강보조식품 소매업   1       3     86  26041090   120
# 3       2019  1    강남구     건강보조식품 소매업   1       4    191  79951020   333
# 4       2019  1    강남구     건강보조식품 소매업   1       5    124  40362670   192
# ...      ... ..    ...            ...  ..     ...    ...       ...   ...
# 106860  2020  3    중랑구  화장품 및 방향제 소매업   2       1    608  12830505   708
# 106861  2020  3    중랑구  화장품 및 방향제 소매업   2       2    492  13213425   568
# 106862  2020  3    중랑구  화장품 및 방향제 소매업   2       3    281   9646440   362
# 106863  2020  3    중랑구  화장품 및 방향제 소매업   2       4   1074  50109146  1286
# 106864  2020  3    중랑구  화장품 및 방향제 소매업   2       5   1008  46687890  1202
#
# [106865 rows x 9 columns]

# %%
df.to_csv('corona_seoul_1.csv',index=False)

# %%
df=df.rename({'확진월':'월','지역':'매장_시군구'},axis='columns')

# %%
df.head()
# Out:
#    월 매장_시군구  확진자수
# 0  1    강서구     1
# 1  1    마포구     1
# 2  1    성북구     1
# 3  1    종로구     3
# 4  1    중랑구     1

# %%
merge_outer = pd.merge(df_1,df, how='outer',on=['월','매장_시군구'])
merge_outer
# Out:
#              년   월 매장_시군구            업종명   성별  가구생애주기   이용고객수        이용금액  \
# 0       2019.0   1    강남구     건강보조식품 소매업  1.0     1.0    31.0   1405000.0
# 1       2019.0   1    강남구     건강보조식품 소매업  1.0     2.0   110.0  11861050.0
# 2       2019.0   1    강남구     건강보조식품 소매업  1.0     3.0    86.0  26041090.0
# 3       2019.0   1    강남구     건강보조식품 소매업  1.0     4.0   191.0  79951020.0
# 4       2019.0   1    강남구     건강보조식품 소매업  1.0     5.0   124.0  40362670.0
# ...        ...  ..    ...            ...  ...     ...     ...         ...
# 106861  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     2.0   677.0  23596535.0
# 106862  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     3.0   410.0  17685140.0
# 106863  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     4.0  1324.0  58628470.0
# 106864  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     5.0  1177.0  58479310.0
# 106865     NaN   3     기타            NaN  NaN     NaN     NaN         NaN
#
#           이용건수  확진자수
# 0         36.0   NaN
# 1        121.0   NaN
# ...

# %%
merge=merge_outer.iloc[:106865,:].fillna(0)

# %%
merge
# Out:
#              년   월 매장_시군구            업종명   성별  가구생애주기   이용고객수        이용금액  \
# 0       2019.0   1    강남구     건강보조식품 소매업  1.0     1.0    31.0   1405000.0
# 1       2019.0   1    강남구     건강보조식품 소매업  1.0     2.0   110.0  11861050.0
# 2       2019.0   1    강남구     건강보조식품 소매업  1.0     3.0    86.0  26041090.0
# 3       2019.0   1    강남구     건강보조식품 소매업  1.0     4.0   191.0  79951020.0
# 4       2019.0   1    강남구     건강보조식품 소매업  1.0     5.0   124.0  40362670.0
# ...        ...  ..    ...            ...  ...     ...     ...         ...
# 106860  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     1.0   781.0  15134953.0
# 106861  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     2.0   677.0  23596535.0
# 106862  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     3.0   410.0  17685140.0
# 106863  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     4.0  1324.0  58628470.0
# 106864  2019.0  12    중랑구  화장품 및 방향제 소매업  2.0     5.0  1177.0  58479310.0
#
#           이용건수  확진자수
# 0         36.0   0.0
# 1        121.0   0.0
# ...

# %%
merge.to_csv('seoul_add_corona.csv',index=False)
